# %% [markdown]
# ### Data Visualization III
# 1. Use Iris Dataset
# 2. List down the features and their types (e.g., numeric, nominal) available in the dataset.
# 3. Create a histogram for each feature in the dataset to illustrate the feature distributions.
# 4. Create a box plot for each feature in the dataset.
# 5. Compare distributions and identify outliers.

# %%
# Import Libraries
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../Datasets/Iris.csv')
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ### Histogram for each Feature

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 1. Sepal Length Histogram
sns.histplot(data=data, x='sepal_length', kde=True, bins=10,hue='species')
plt.show()

# %%
# 2. Petal Length Histogram
sns.histplot(data=data, x='petal_length', kde=True, bins=10,hue="species")
plt.title('Distribution of Petal Length')
plt.show()

# %%
# 3. Petal Width Histogram
sns.histplot(data=data, x='petal_width', kde=True, bins=10,hue="species")
plt.show()

# %%
# 4. Sepal Width Histogram
sns.histplot(data=data, x='sepal_width', kde=True, bins=10,hue="species")
plt.show()

# %% [markdown]
# ### Feature Distribution

# %%
sns.boxplot(data=data.drop(["species"],axis=1))
# Out:
# <Axes: >

# %%
sns.boxplot(data=data, x="species", y="sepal_length")
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.boxplot(data=data, x="species", y="sepal_width")
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
sns.boxplot(data=data, x="species", y="petal_length")
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
sns.boxplot(data=data, x="species", y="petal_width")
# Out:
# <Axes: xlabel='species', ylabel='petal_width'>

# %% [markdown]
# ### Comparing distribution with kde plot

# %%
sns.kdeplot(data=data, x="sepal_length",fill=True,hue="species")
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
sns.kdeplot(data=data, x="petal_length",fill=True,hue="species")
# Out:
# <Axes: xlabel='petal_length', ylabel='Density'>

# %%
sns.kdeplot(data=data, x="sepal_width",fill=True,hue="species")
# Out:
# <Axes: xlabel='sepal_width', ylabel='Density'>

# %%
sns.kdeplot(data=data, x="petal_width",fill=True,hue="species")
# Out:
# <Axes: xlabel='petal_width', ylabel='Density'>

# %%
data[["sepal_length","sepal_width","petal_length","petal_width"]].corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000
